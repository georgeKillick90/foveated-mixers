# %%
from src.models import resmlp_s12, vit_s12, STN, Localizer
from src.tokenizers import foveated_tokenizer, Patchify
from src.training import train, test
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader
from src.resmlp import resmlp_s12_224

from torchvision.models import resnet18

# %%
def resnet():
    model = resnet18()
    model.fc = nn.Linear(512, 10)
    return model

# %%
from torch.optim import AdamW
from torch.optim.lr_scheduler import OneCycleLR

def get_transforms():
    
    mean, std = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]
    
    train_transforms = [transforms.Resize(256),
                        transforms.TrivialAugmentWide(),
                        transforms.RandomResizedCrop((224,224), scale=(0.08, 1.0)),
                        transforms.ToTensor(),
                        transforms.Normalize(mean=mean, std=std)]
    
    test_transforms = [transforms.Resize(256),
                       transforms.CenterCrop((224,224)),
                       transforms.ToTensor(),
                       transforms.Normalize(mean=mean, std=std)]
    
    return transforms.Compose(train_transforms), transforms.Compose(test_transforms)

def get_dataloaders(root, batch_size, **kwargs):
    
    train_transform, test_transform = get_transforms()
    
    _train_dataset = ImageFolder(root + "imagewoof2-320/train", transform=train_transform)
    _valid_dataset = ImageFolder(root + "imagewoof2-320/train", transform=test_transform)
    test_dataset = ImageFolder(root + "imagewoof2-320/val", transform=test_transform)
    
    # split the dataset 
    indices = torch.randperm(len(_train_dataset))
    val_size = len(_train_dataset)//10
    train_dataset = torch.utils.data.Subset(_train_dataset, indices[:-val_size])
    valid_dataset = torch.utils.data.Subset(_valid_dataset, indices[-val_size:])
    
    train_loader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=4, **kwargs)
    valid_loader = DataLoader(valid_dataset, batch_size, shuffle=False, num_workers=4, **kwargs)
    test_loader = DataLoader(test_dataset, batch_size, shuffle=False, num_workers=4, **kwargs)
    
    return train_loader, valid_loader, test_loader
    
def init_model(n_classes):
    tokenizer = Patchify(224, 16, 3, 384)
    classifier = resmlp_s12(n_classes, init_value=0.1)
    return nn.Sequential(tokenizer, classifier)

def init_stn_optimizer(
    model,
    steps_per_epoch,
    num_epochs,
    max_lr,
    weight_decay,
):
    
    weight_decay_params = []
    no_weight_decay_params = []
    
    for name, param in model.named_parameters():
        if ('bias' in name) or ('norm' in name) or ('saliency' in name) or ('layerscale' in name):
            no_weight_decay_params.append(param)
        else:
            weight_decay_params.append(param)
            
    opt = AdamW([{'params': weight_decay_params, 'lr': max_lr, 'weight_decay': weight_decay},
                 {"params": no_weight_decay_params, 'lr': max_lr, 'weight_decay': 0.0}])
        
    
    scheduler = OneCycleLR(
        opt,
        max_lr=max_lr,
        total_steps = steps_per_epoch * num_epochs,
    )
    
    scaler = torch.cuda.amp.GradScaler()
    return opt, scheduler, scaler

# %%
EPOCHS = 90
BATCH_SIZE = 256

train_loader, valid_loader, test_loader = get_dataloaders("../Datasets/", batch_size=BATCH_SIZE)

model = init_model(10)
optimizer, scheduler, scaler = init_stn_optimizer(model, len(train_loader), EPOCHS, 0.004, 0.0125)

train(model, optimizer, scheduler, scaler, train_loader, valid_loader, EPOCHS)

test(model, test_loader)
# Out:
# ### Training ###
#
# Epoch 0: [------------------------------]
#
# Batch: 0 - Loss: 2.36 --- Accuracy: 8.59
# Batch: 5 - Loss: 2.29 --- Accuracy: 15.23
# Batch: 10 - Loss: 2.32 --- Accuracy: 14.84
# Batch: 15 - Loss: 2.25 --- Accuracy: 17.58
# Batch: 20 - Loss: 2.27 --- Accuracy: 13.28
# Batch: 25 - Loss: 2.23 --- Accuracy: 13.67
# Batch: 30 - Loss: 2.23 --- Accuracy: 16.80
#
# Average Train Loss: 2.26 - Average Train Accuracy 15.14
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 2.19 - Average Validation Accuracy 21.18
#
# Epoch 1: [------------------------------]
#
# Batch: 0 - Loss: 2.22 --- Accuracy: 18.36
# Batch: 5 - Loss: 2.20 --- Accuracy: 21.48
# Batch: 10 - Loss: 2.21 --- Accuracy: 18.36
# Batch: 15 - Loss: 2.21 --- Accuracy: 15.23
# Batch: 20 - Loss: 2.20 --- Accuracy: 17.19
# Batch: 25 - Loss: 2.18 --- Accuracy: 22.66
# Batch: 30 - Loss: 2.19 --- Accuracy: 16.41
#
# Average Train Loss: 2.21 - Average Train Accuracy 18.60
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 2.09 - Average Validation Accuracy 22.39
#
# Epoch 2: [------------------------------]
#
# Batch: 0 - Loss: 2.20 --- Accuracy: 20.31
# Batch: 5 - Loss: 2.18 --- Accuracy: 16.02
# Batch: 10 - Loss: 2.14 --- Accuracy: 22.66
# Batch: 15 - Loss: 2.19 --- Accuracy: 20.31
# Batch: 20 - Loss: 2.20 --- Accuracy: 23.05
# Batch: 25 - Loss: 2.20 --- Accuracy: 19.53
# Batch: 30 - Loss: 2.17 --- Accuracy: 23.05
#
# Average Train Loss: 2.18 - Average Train Accuracy 20.36
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 2.07 - Average Validation Accuracy 23.95
#
# Epoch 3: [#-----------------------------]
#
# Batch: 0 - Loss: 2.19 --- Accuracy: 17.19
# Batch: 5 - Loss: 2.16 --- Accuracy: 25.78
# Batch: 10 - Loss: 2.19 --- Accuracy: 15.62
# Batch: 15 - Loss: 2.15 --- Accuracy: 25.39
# Batch: 20 - Loss: 2.13 --- Accuracy: 23.44
# Batch: 25 - Loss: 2.16 --- Accuracy: 22.27
# Batch: 30 - Loss: 2.16 --- Accuracy: 20.70
#
# Average Train Loss: 2.16 - Average Train Accuracy 21.85
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 2.03 - Average Validation Accuracy 29.93
#
# Epoch 4: [#-----------------------------]
#
# Batch: 0 - Loss: 2.13 --- Accuracy: 21.88
# Batch: 5 - Loss: 2.13 --- Accuracy: 21.88
# Batch: 10 - Loss: 2.18 --- Accuracy: 22.27
# Batch: 15 - Loss: 2.20 --- Accuracy: 20.31
# Batch: 20 - Loss: 2.17 --- Accuracy: 23.83
# Batch: 25 - Loss: 2.11 --- Accuracy: 25.39
# Batch: 30 - Loss: 2.16 --- Accuracy: 23.05
#
# Average Train Loss: 2.15 - Average Train Accuracy 22.96
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 2.04 - Average Validation Accuracy 28.94
#
# Epoch 5: [#-----------------------------]
#
# Batch: 0 - Loss: 2.17 --- Accuracy: 21.48
# Batch: 5 - Loss: 2.10 --- Accuracy: 27.73
# Batch: 10 - Loss: 2.14 --- Accuracy: 22.27
# Batch: 15 - Loss: 2.16 --- Accuracy: 20.31
# Batch: 20 - Loss: 2.15 --- Accuracy: 26.17
# Batch: 25 - Loss: 2.18 --- Accuracy: 19.14
# Batch: 30 - Loss: 2.15 --- Accuracy: 24.22
#
# Average Train Loss: 2.14 - Average Train Accuracy 23.09
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 1.99 - Average Validation Accuracy 29.93
#
# Epoch 6: [##----------------------------]
#
# Batch: 0 - Loss: 2.07 --- Accuracy: 27.73
# Batch: 5 - Loss: 2.18 --- Accuracy: 21.88
# Batch: 10 - Loss: 2.13 --- Accuracy: 26.17
# Batch: 15 - Loss: 2.15 --- Accuracy: 25.78
# Batch: 20 - Loss: 2.08 --- Accuracy: 28.91
# Batch: 25 - Loss: 2.16 --- Accuracy: 20.70
# Batch: 30 - Loss: 2.11 --- Accuracy: 25.39
#
# Average Train Loss: 2.14 - Average Train Accuracy 23.58
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 2.02 - Average Validation Accuracy 28.82
#
# Epoch 7: [##----------------------------]
#
# Batch: 0 - Loss: 2.21 --- Accuracy: 23.44
# Batch: 5 - Loss: 2.08 --- Accuracy: 25.39
# Batch: 10 - Loss: 2.13 --- Accuracy: 22.66
# Batch: 15 - Loss: 2.13 --- Accuracy: 23.83
# Batch: 20 - Loss: 2.18 --- Accuracy: 18.75
# Batch: 25 - Loss: 2.13 --- Accuracy: 23.05
# Batch: 30 - Loss: 2.16 --- Accuracy: 19.14
#
# Average Train Loss: 2.14 - Average Train Accuracy 23.24
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 2.02 - Average Validation Accuracy 27.83
#
# Epoch 8: [##----------------------------]
#
# Batch: 0 - Loss: 2.13 --- Accuracy: 23.44
# Batch: 5 - Loss: 2.15 --- Accuracy: 22.66
# Batch: 10 - Loss: 2.12 --- Accuracy: 22.27
# Batch: 15 - Loss: 2.11 --- Accuracy: 23.05
# Batch: 20 - Loss: 2.08 --- Accuracy: 26.17
# Batch: 25 - Loss: 2.17 --- Accuracy: 22.27
# Batch: 30 - Loss: 2.14 --- Accuracy: 25.78
#
# Average Train Loss: 2.13 - Average Train Accuracy 23.71
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 1.92 - Average Validation Accuracy 30.38
#
# Epoch 9: [###---------------------------]
#
# Batch: 0 - Loss: 2.10 --- Accuracy: 23.83
# Batch: 5 - Loss: 2.11 --- Accuracy: 23.83
# Batch: 10 - Loss: 2.07 --- Accuracy: 27.73
# Batch: 15 - Loss: 2.11 --- Accuracy: 25.78
# Batch: 20 - Loss: 2.11 --- Accuracy: 18.75
# Batch: 25 - Loss: 2.15 --- Accuracy: 19.92
# Batch: 30 - Loss: 2.18 --- Accuracy: 23.44
#
# Average Train Loss: 2.12 - Average Train Accuracy 24.29
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 1.99 - Average Validation Accuracy 27.49
#
# Epoch 10: [###---------------------------]
#
# Batch: 0 - Loss: 2.12 --- Accuracy: 24.22
# Batch: 5 - Loss: 2.06 --- Accuracy: 31.64
# Batch: 10 - Loss: 2.19 --- Accuracy: 20.31
# Batch: 15 - Loss: 2.14 --- Accuracy: 21.48
# Batch: 20 - Loss: 2.13 --- Accuracy: 24.22
# Batch: 25 - Loss: 2.14 --- Accuracy: 23.83
# Batch: 30 - Loss: 2.13 --- Accuracy: 24.22
#
# Average Train Loss: 2.13 - Average Train Accuracy 24.24
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 1.96 - Average Validation Accuracy 28.60
#
# Epoch 11: [###---------------------------]
#
# Batch: 0 - Loss: 2.13 --- Accuracy: 23.44
# Batch: 5 - Loss: 2.12 --- Accuracy: 18.36
# Batch: 10 - Loss: 2.08 --- Accuracy: 27.73
# Batch: 15 - Loss: 2.11 --- Accuracy: 25.78
# Batch: 20 - Loss: 2.13 --- Accuracy: 25.78
# Batch: 25 - Loss: 2.18 --- Accuracy: 23.05
# Batch: 30 - Loss: 2.04 --- Accuracy: 28.52
#
# Average Train Loss: 2.11 - Average Train Accuracy 25.03
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 1.92 - Average Validation Accuracy 30.82
#
# Epoch 12: [####--------------------------]
#
# Batch: 0 - Loss: 2.06 --- Accuracy: 26.95
# Batch: 5 - Loss: 2.15 --- Accuracy: 23.83
# Batch: 10 - Loss: 2.11 --- Accuracy: 26.17
# Batch: 15 - Loss: 2.07 --- Accuracy: 28.12
# Batch: 20 - Loss: 2.08 --- Accuracy: 26.56
# Batch: 25 - Loss: 2.08 --- Accuracy: 30.47
# Batch: 30 - Loss: 2.09 --- Accuracy: 23.83
#
# Average Train Loss: 2.10 - Average Train Accuracy 25.54
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 1.86 - Average Validation Accuracy 34.26
#
# Epoch 13: [####--------------------------]
#
# Batch: 0 - Loss: 2.19 --- Accuracy: 18.75
# Batch: 5 - Loss: 2.12 --- Accuracy: 20.31
# Batch: 10 - Loss: 2.14 --- Accuracy: 21.09
# Batch: 15 - Loss: 2.11 --- Accuracy: 22.66
# Batch: 20 - Loss: 2.04 --- Accuracy: 28.91
# Batch: 25 - Loss: 2.16 --- Accuracy: 20.31
# Batch: 30 - Loss: 2.08 --- Accuracy: 27.34
#
# Average Train Loss: 2.09 - Average Train Accuracy 26.12
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 1.91 - Average Validation Accuracy 30.60
#
# Epoch 14: [####--------------------------]
#
# Batch: 0 - Loss: 2.05 --- Accuracy: 27.34
# Batch: 5 - Loss: 2.14 --- Accuracy: 20.31
# Batch: 10 - Loss: 2.09 --- Accuracy: 26.56
# Batch: 15 - Loss: 2.09 --- Accuracy: 27.73
# Batch: 20 - Loss: 2.03 --- Accuracy: 30.08
# Batch: 25 - Loss: 2.07 --- Accuracy: 28.52
# Batch: 30 - Loss: 2.09 --- Accuracy: 23.83
#
# Average Train Loss: 2.08 - Average Train Accuracy 26.16
#
# ### Validation and Checkpointing ###
#
# Average Validation Loss: 1.93 - Average Validation Accuracy 33.92
#
# Epoch 15: [#####-------------------------]
#
# Batch: 0 - Loss: 2.09 --- Accuracy: 25.00
# KeyboardInterrupt
